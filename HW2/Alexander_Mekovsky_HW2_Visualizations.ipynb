# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
data = pd.read_csv('scores.csv')
data
# Out:
#      Accuracy        F1  Train_Loss  Val_Loss
# 0   95.433928  0.954342    0.335190  0.130713
# 1   95.796795  0.957956    0.147606  0.277253
# 2   96.371334  0.963725    0.130688  0.128758
# 3   96.492289  0.964936    0.122410  0.194186
# 4   96.220139  0.962194    0.114368  0.081372
# ..        ...       ...         ...       ...
# 95  96.310856  0.963101    0.004484  0.000089
# 96  96.492289  0.964922    0.002008  0.000025
# 97  96.250378  0.962517    0.007300  0.006331
# 98  96.462050  0.964634    0.004575  0.001104
# 99  96.220139  0.962209    0.001866  0.000030
#
# [100 rows x 4 columns]

# %%
acc = data['Accuracy']
f1 = data['F1']
f1 = f1 * 100
train = data['Train_Loss']
val = data['Val_Loss']

# %%
figure(figsize = (16, 8))
plt.plot(acc)
plt.plot(f1)
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.legend(['Accuracy','F1'])
plt.show()

# %%
figure(figsize = (16, 8))
plt.plot(train)
plt.plot(val)
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.legend(['Train_Loss','Val_Loss'])
plt.show()
